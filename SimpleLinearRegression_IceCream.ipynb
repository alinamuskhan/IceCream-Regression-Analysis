# %%
import pandas as pd
import numpy as np

# %%
import piplite
await piplite.install('seaborn')
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("Ice Cream.csv")

# %%
df
# Out:
#      Temperature  Revenue
# 0           24.6      535
# 1           26.1      626
# 2           27.8      661
# 3           20.6      488
# 4           11.6      317
# ..           ...      ...
# 495         22.3      525
# 496         32.9      756
# 497         12.6      307
# 498         22.4      567
# 499         29.0      656
#
# [500 rows x 2 columns]

# %%
df.shape
# Out:
# (500, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.281600   522.058000
# std       8.097597   175.410399
# min       0.000000    10.000000
# 25%      17.175000   406.000000
# 50%      22.400000   530.000000
# 75%      27.800000   643.000000
# max      45.000000  1000.000000

# %%
df.isnull().sum()
# Out:
# Temperature    0
# Revenue        0
# dtype: int64

# %%
df.nunique()
# Out:
# Temperature    250
# Revenue        344
# dtype: int64

# %%
df.head(10)
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317
# 5         14.4      368
# 6         13.8      309
# 7         30.9      697
# 8          1.0       56
# 9         31.7      738

# %%
df.tail(10)
# Out:
#      Temperature  Revenue
# 490         23.9      585
# 491         34.5      810
# 492         23.1      553
# 493         15.0      378
# 494         25.2      572
# 495         22.3      525
# 496         32.9      756
# 497         12.6      307
# 498         22.4      567
# 499         29.0      656

# %%
plt.figure(figsize=(6,5))
sns.scatterplot(x="Temperature",y="Revenue",data=df)
plt.grid()

# %%
plt.figure(figsize=(6,5))
sns.regplot(x="Temperature",y="Revenue",data=df,line_kws={'color':'red'})
plt.grid()

# %%
x=df["Temperature"]
y=df["Revenue"]

# %%
x
# Out:
# 0      24.6
# 1      26.1
# 2      27.8
# 3      20.6
# 4      11.6
#        ...
# 495    22.3
# 496    32.9
# 497    12.6
# 498    22.4
# 499    29.0
# Name: Temperature, Length: 500, dtype: float64

# %%
y
# Out:
# 0      535
# 1      626
# 2      661
# 3      488
# 4      317
#       ...
# 495    525
# 496    756
# 497    307
# 498    567
# 499    656
# Name: Revenue, Length: 500, dtype: int64

# %%
x=np.array(x)
y=np.array(y)

# %%
x
# Out:
# array([24.6, 26.1, 27.8, 20.6, 11.6, 14.4, 13.8, 30.9,  1. , 31.7, 11.5,
#         3.7, 18.9, 13.7, 39.6, 18.5, 26. , 42.6, 29.6, 21.8, 25.5, 15.3,
#        22.7, 16.3, 23.9, 19. , 15.7, 29.2, 19.1, 35.2, 24.2, 15.3,  8.8,
#        18.3, 35.7, 37.1, 22.3, 17.6, 31.8, 17.1, 23.1,  8.8, 18.8, 14.2,
#        18.7, 15.7, 21. , 30.7, 20.5, 31.3,  6.4, 27.2, 28.7, 28. , 10.4,
#        27.4, 33.3, 36.6, 12.5, 14.4, 16.4, 11.6, 33.6,  4. , 20.6,  6.6,
#        12.8, 24.6, 39.8, 30.3, 24.5, 20.3, 20.3, 14.9, 28.8, 29.8, 26.4,
#         6.8, 23.3, 24.4, 25.8, 21.7, 26.2, 21.7, 18.9,  0.3, 19.7, 20.2,
#        24. , 29.3, 34.9, 11.2, 26.2, 39.9, 20.5, 17.9, 18.4, 10. , 25.1,
#        12.1, 37. , 14.8,  7.2, 38.1, 27. , 12.5, 10.2, 17.6, 12.1, 30.5,
#         7.4, 22.7, 28.1, 33.6, 24.3, 38.7,  0. , 24.4, 26.2,  5.4, 18. ,
#        31. , 29.8, 32.7, 21.2, 18.6, 14.6, 41.8, 27.2, 20.1, 20.6, 27.6,
#        30.3, 21.7, 20.1, 17.3, 17.2, 35.5, 19.2, 19. , 26.2, 20. , 27.8,
#        21.1, 25.4, 24.2, 27.6,  8.8, 27.6, 16. , 17.2, 28.8, 17.2,  8.8,
#        31.1, 19.3, 27.2, 30.1, 45. , 19. , 15.2, 21.9, 29.6, 19.3, 29.9,
#        21.7, 25. , 31.2, 34.7, 21. , 37.2, 26.4, 35.4, 24.5, 38.7, 29. ,
#        12.2, 11.6, 17.5, 20.9, 40.4, 26.6, 39.6, 22.4,  9.4, 19.5, 22.3,
#        18.9, 21.8, 18.2, 14.9, 28.9, 25.4, 18.6, 22.5, 30.1, 17. , 27.3,
#         4.9, 23.5, 12.4, 32.7, 16.8, 27. , 23.9, 34.5, 23.1, 15. , 25.2,
#        22.3, 32.9, 12.6, 22.4, 29. ])

# %%
y
# Out:
# array([ 535,  626,  661,  488,  317,  368,  309,  697,   56,  738,  326,
#          72,  468,  290,  906,  470,  649,  922,  650,  535,  613,  354,
#         525,  375,  524,  474,  403,  680,  518,  810,  529,  357,  238,
#         419,  810,  871,  551,  406,  741,  502,  540,  243,  422,  359,
#         468,  397,  501,  652,  452,  698,  191,  622,  667,  629,  220,
#         624,  750,  828,  304,  352,  382,  322,  775,  132,  499,  196,
#         497,  285,  484,  431,  277,  628,  644,  624,  587,  654,  919,
#         592,  652,  683,  373,  382,  516,  686,  655,  407,  644,  345,
#         643,  362,  705,  223,  544,  222,  338,  213,  475,  461,  344,
#         284,  469,  712,  323,  402,  628,  416,  554,  363,  644,  652,
#         604,  428,  566,  734,  386,  690,  573,  720,  307,  597,  541,
#         342,  656,  703,  320,  451,  383,  675,  732,  752,  497,  418,
#         449,  478,  159,  517,  600,  657,  508,  280,  842,  484,  740,
#         487,  457,  242,  619,  447,  604,  275,  532,  298,  320,  494,
#         587,  498,  477,  626,  391,  676,  274,  281,  584,  649,  727,
#         336,  571,  686,  776,  774,  541,  367,  540,  810,  377,  478,
#         521,  655,  519,  783,  251,  635,  489,  521,  653,  384,  797,
#         294,  415,  692,  340,  472,  500,  543,  402,  681,  259,  716,
#         609,  575,  616,  534,  579,  279,  187,  396,  538,  229,  604,
#         273,  494,  613,  438,  507,  410,  563,  403,  533,  414,  333,
#         564,  473,  597,  597,  269,  529,  628,  619,  851,  119,  279,
#         450,  449,  464,  475,  825,  554,  697,  676,  696,  289,  507,
#         619,  368,  192,  335,  584,  539,  395,  474,  428,  748,  213,
#         692,  633,  449,  522,  438,  707,  406,  504,  571,  707,  544,
#         642,  275,  421,  146,  829,  595,  604,  652,  608,  626,  536,
#         531,  536,  782,  798,  522,  608,  535,  600,  663,  513,  575,
#         551,  555,  497,  351,  410,  632,  662,  643,  322,  413,  539,
#         858,  426,  199,  171,  600,  559,  551,  715,  527,  760,  442,
#         757,  543,  455,  336,  576,  595,  622,  521,  588,  538,  640,
#         468,  375,  605,  464,  551,  316,  224,  564,  490,  459,  966,
#         690,  679,  380,  509,  685,  599,  417,  572,  772,  236,  580,
#         407,  537,  250,  703,  336,  808,  565,  857,  483,  437,  217,
#         296,  595,  936,  649,  597,  499,  476,  385,  634,  660,  610,
#         200,  556,  595,  573,  479,  564,  546,  445,   33,  507,  492,
#         560,  698,  799,  279,  595,  876,  514,  441,  411,  257,  584,
#         279,  852,  323,  222,  820,  645,  284,  277,  403,  301,  691,
#         193,  547,  666,  751,  570,  917,   10,  573,  659,  243,  442,
#         703,  644,  819,  494,  444,  324,  970,  659,  478,  426,  650,
#         680,  506,  474,  406,  429,  801,  446,  451,  618,  542,  655,
#         522,  604,  589,  635,  247,  641,  382,  391,  655,  413,  265,
#         685,  460,  616,  699, 1000,  450,  323,  494,  630,  453,  684,
#         538,  609,  747,  757,  492,  893,  647,  805,  527,  892,  637,
#         298,  258,  392,  495,  927,  613,  899,  490,  292,  430,  501,
#         476,  531,  454,  297,  683,  582,  433,  508,  692,  449,  613,
#         189,  502,  334,  794,  380,  582,  585,  810,  553,  378,  572,
#         525,  756,  307,  567,  656], dtype=int64)

# %%
x=x.reshape(-1,1)
x.shape
# Out:
# (500, 1)

# %%
y=y.reshape(-1,1)
y.shape
# Out:
# (500, 1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (400, 1)

# %%
x_test.shape
# Out:
# (100, 1)

# %%
y_train.shape
# Out:
# (400, 1)

# %%
y_test.shape
# Out:
# (100, 1)

# %%
from sklearn.linear_model import LinearRegression
SimpleLinearRegression=LinearRegression(fit_intercept=True)
SimpleLinearRegression.fit(x_train,y_train)
print('Coefficient(m)',SimpleLinearRegression.coef_)
print('intercept(b)',SimpleLinearRegression.intercept_)
# Out:
# Coefficient(m) [[21.46374133]]
# intercept(b) [43.53417381]

# %%
plt.scatter(x_train,y_train,color='green')
plt.plot(x_train,SimpleLinearRegression.predict(x_train),color='red')
plt.xlabel("Revenue")
plt.ylabel("Temperature")
plt.title("Temperature vs Revenue generated")
plt.grid()

# %%
plt.scatter(x_test,y_test,color='green')
plt.plot(x_test,SimpleLinearRegression.predict(x_test),color='red')
plt.xlabel("Revenue")
plt.ylabel("Temperature")
plt.title("Temperature vs Revenue generated")
plt.grid()

# %%
temp=np.array([20])
temp=temp.reshape(-1,1)

Revenue=SimpleLinearRegression.predict(temp)
print("R")
